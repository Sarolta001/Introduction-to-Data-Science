# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Sarolta Bolla**
# <br>
# Financial analyst

# %% [markdown]
# *I am interested in data science because I see tremendous potential of analyzing data and preparing models based on it. Taking into consideration the outcomes of these models we can have the chance to predict future events more precisely and use this knowledge to get better off and avoid unfortunate happenings.*

# %% [markdown]
# ### Let's calculate the addition of two numerical values (numbers).

# %%
1+1
# Out:
# 2

# %% [markdown]
#  * Today is Sunday, the 6th of December
# <hr>
#  - It is the day when Santa Claus comes.
#  <hr>
#  + So what to do today?
#  <hr>
#  1. Waiting for Santa Claus
#  1. Expecting nice presents
#  1. Eating chocolate and cookies
#  1. Watching the film Frozen
#  <hr>
#  + Wishlist
#  <hr>
#
#
# | chocolates | candies | socks | candles | games | toys |
# | --- | --- | --- | --- | --- | --- |
# | yes | no | yes| no | yes | yes |
#
#
#  <hr>
#   <strike>No studying for today.<strike>
#  <hr>
